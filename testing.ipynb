# %%
import pandas as pd

# %%
df=pd.read_csv('./redis/sample_df.csv')

# %%
df
# Out:
#    Unnamed: 0  Unnamed: 0.1  step  age gender  zipcodeOri  zipMerchant  \
# 0          26            26    92    3      M       28007        28007
# 1          69            69    76    3      F       28007        28007
# 2          82            82   114    1      F       28007        28007
# 3          98            98   127    3      M       28007        28007
# 4          70            70    76    3      F       28007        28007
# 5          41            41    99    4      M       28007        28007
# 6          99            99   127    3      M       28007        28007
# 7          96            96   127    3      M       28007        28007
# 8          62            62    76    3      F       28007        28007
# 9          55            55    76    3      F       28007        28007
#
#                category  amount  fraud    timestampsource_transaction  \
# 0     es_transportation   56.78      0  2022-07-27 18:54:23.114820214
# ...

# %%
df.pop('Unnamed: 0')
df.pop('Unnamed: 0.1')
# Out:
# 0    26
# 1    69
# 2    82
# 3    98
# 4    70
# 5    41
# 6    99
# 7    96
# 8    62
# 9    55
# Name: Unnamed: 0.1, dtype: int64

# %%
df.to_csv('./redis/sample_df.csv',index=False)
