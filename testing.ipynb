# %%
import pandas as pd

# %%
from datetime import datetime
import time

# %%
df=pd.read_csv('./redis/sample_df.csv')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
for i in df.index:
    df.loc[i,'timestampsource_user_data']=str(datetime.now())
    time.sleep(2)

# %%
df
# Out:
#    step  age gender  zipcodeOri  zipMerchant              category  amount  \
# 0    92    3      M       28007        28007     es_transportation   56.78
# 1    76    3      F       28007        28007     es_transportation   17.11
# 2   114    1      F       28007        28007           es_contents   65.88
# 3   127    3      M       28007        28007     es_transportation   16.06
# 4    76    3      F       28007        28007     es_transportation   17.11
# 5    99    4      M       28007        28007  es_wellnessandbeauty  194.65
# 6   127    3      M       28007        28007     es_transportation   16.06
# 7   127    3      M       28007        28007     es_transportation   16.06
# 8    76    3      F       28007        28007     es_transportation   17.11
# 9    76    3      F       28007        28007     es_transportation   17.11
#
#    fraud    timestampsource_transaction       source       target  \
# 0      0  2022-07-27 18:54:23.114820214  C1150646122  M1823072687
# ...

# %%
df.to_csv('./redis/sample_df_2.csv',index=False)
